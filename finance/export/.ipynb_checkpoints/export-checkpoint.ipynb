# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('2019 NIGERIAN IMPORT DATA.xlsx')
df.shape
# Out:
# (62240, 27)

# %%
df.head()
# Out:
#        S/N SCANNING_COY PREFIX  BANK_CODE                       BNK_NAM  \
# 0   9577.0          NCS     BA      214.0  First City Monument Bank PLC
# 1   6756.0          NCS     BA       44.0               Access Bank PLC
# 2  17380.0          NCS     BA       23.0      Citibank Nigeria Limited
# 3  18398.0          NCS     BA       23.0      Citibank Nigeria Limited
# 4   4799.0          NCS     BA       23.0      Citibank Nigeria Limited
#
#    BANK_NUMBERING          MFNUM  APP_YEAR AUTHORIZED_DEALER_DATE  EXC_RATE  \
# 0    2.019000e+10  MF20190010578    2019.0             2019-01-31     0.534
# 1    2.019000e+10  MF20190006942    2019.0             2019-01-23   311.738
# 2    2.019000e+10  MF20190018966    2019.0             2019-02-27   308.819
# 3    2.019000e+10  MF20190020044    2019.0             2019-03-01   308.819
# 4    2.019000e+10  MF20190036985    2019.0             2019-04-12   308.214
#
#    ...               APPLICANT_NAME  \
# ...

# %%
# let's check unique values
columns=df.columns
for col in columns:
    print(col,':\n',df[col].unique())
    print(df[col].value_counts())
    print('\n',20*'**','\n')
# Out:
# S/N :
#  [ 9577.  6756. 17380. ... 31796. 37455.    nan]
# 4715.0     2
# 22415.0    2
# 22461.0    2
# 8785.0     2
# 9302.0     2
#           ..
# 70642.0    1
# 70729.0    1
# 71067.0    1
# 71229.0    1
# 37455.0    1
# Name: S/N, Length: 53892, dtype: int64
#
#  ****************************************
#
# SCANNING_COY :
#  ['NCS' nan]
# NCS    62238
# Name: SCANNING_COY, dtype: int64
#
#  ****************************************
#
# PREFIX :
#  ['BA' 'CB' nan]
# BA    61596
# CB      642
# Name: PREFIX, dtype: int64
#
#  ****************************************
#
# BANK_CODE :
#  [214.  44.  23.  58. 221.  33.  57.  70.  11.  82.  76. 101.  68.  32.
#  215.  63.  50. 501. 232.  35.  30. 301. 561. 560. 100.  nan]
# 57.0     12882
# 44.0      7147
# 221.0     4977
# 68.0      4909
# 23.0      4039
# 11.0      3858
# 58.0      3580
# 33.0      3506
# 32.0      3079
# 70.0      2948
# 214.0     2700
# 50.0      2013
# 232.0     1499
# 76.0      1431
# 35.0       968
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62240 entries, 0 to 62239
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   S/N                     62238 non-null  float64
#  1   SCANNING_COY            62238 non-null  object
#  2   PREFIX                  62238 non-null  object
#  3   BANK_CODE               62238 non-null  float64
#  4   BNK_NAM                 62238 non-null  object
#  5   BANK_NUMBERING          62238 non-null  float64
#  6   MFNUM                   62238 non-null  object
#  7   APP_YEAR                62238 non-null  float64
#  8   AUTHORIZED_DEALER_DATE  62238 non-null  datetime64[ns]
#  9   EXC_RATE                62238 non-null  float64
#  10  CURRENCY                62238 non-null  object
#  11  FOB_VAL                 62238 non-null  float64
#  12  FREIGHT_VAL             62238 non-null  float64
#  13  CFR                     62238 non-null  float64
# ...

# %%
#Check For Duplicates
duplicates = df.duplicated()
duplicates.sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# S/N                           2
# SCANNING_COY                  2
# PREFIX                        2
# BANK_CODE                     2
# BNK_NAM                       2
# BANK_NUMBERING                2
# MFNUM                         2
# APP_YEAR                      2
# AUTHORIZED_DEALER_DATE        2
# EXC_RATE                      2
# CURRENCY                      2
# FOB_VAL                       2
# FREIGHT_VAL                   2
# CFR                           2
# USD EQUIV                     1
# PAYMENT_MODE                  2
# APPLICANT_RCN_CODE            2
# APPLICANT_NAME                2
# IMPORTER_ADDRESS              2
# IMPORTER_EMAIL              138
# EXPORTER                      2
# EXPORTER_ADDRESS              2
# EXPORTER_EMAIL                2
# ITEM                          3
# Bank Code                 30844
# Bank name                 62240
# FOB Value Naira               1
# dtype: int64

# %%
df = df.fillna(df.mode().iloc[0])

# %%
df.isna().sum()
# Out:
# S/N                           0
# SCANNING_COY                  0
# PREFIX                        0
# BANK_CODE                     0
# BNK_NAM                       0
# BANK_NUMBERING                0
# MFNUM                         0
# APP_YEAR                      0
# AUTHORIZED_DEALER_DATE        0
# EXC_RATE                      0
# CURRENCY                      0
# FOB_VAL                       0
# FREIGHT_VAL                   0
# CFR                           0
# USD EQUIV                     0
# PAYMENT_MODE                  0
# APPLICANT_RCN_CODE            0
# APPLICANT_NAME                0
# IMPORTER_ADDRESS              0
# IMPORTER_EMAIL                0
# EXPORTER                      0
# EXPORTER_ADDRESS              0
# EXPORTER_EMAIL                0
# ITEM                          0
# Bank Code                     0
# Bank name                 62240
# FOB Value Naira               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['S/N', 'SCANNING_COY', 'PREFIX', 'BANK_CODE', 'BNK_NAM',
#        'BANK_NUMBERING', 'MFNUM', 'APP_YEAR', 'AUTHORIZED_DEALER_DATE',
#        'EXC_RATE', 'CURRENCY', 'FOB_VAL', 'FREIGHT_VAL', 'CFR', 'USD EQUIV',
#        'PAYMENT_MODE', 'APPLICANT_RCN_CODE', 'APPLICANT_NAME',
#        'IMPORTER_ADDRESS', 'IMPORTER_EMAIL', 'EXPORTER', 'EXPORTER_ADDRESS',
#        'EXPORTER_EMAIL', 'ITEM', 'Bank Code', 'Bank name', 'FOB Value Naira'],
#       dtype='object')

# %%
df.drop([ 'S/N', 'SCANNING_COY', 'BANK_CODE', 'BANK_NUMBERING', 'MFNUM','FOB_VAL', 'FREIGHT_VAL','USD EQUIV', 'Bank Code', 'Bank name', 'FOB Value Naira', 'CFR'],axis = 1,inplace = True)

# %%
df.head()
# Out:
#   PREFIX                       BNK_NAM  APP_YEAR AUTHORIZED_DEALER_DATE  \
# 0     BA  First City Monument Bank PLC    2019.0             2019-01-31
# 1     BA               Access Bank PLC    2019.0             2019-01-23
# 2     BA      Citibank Nigeria Limited    2019.0             2019-02-27
# 3     BA      Citibank Nigeria Limited    2019.0             2019-03-01
# 4     BA      Citibank Nigeria Limited    2019.0             2019-04-12
#
#    EXC_RATE CURRENCY          PAYMENT_MODE APPLICANT_RCN_CODE  \
# 0     0.534      CFA  Bills for Collection      16298228-0001
# 1   311.738      CHF  Bills for Collection      00389604-0001
# 2   308.819      CHF  Bills for Collection      00389604-0001
# 3   308.819      CHF  Bills for Collection      00389604-0001
# 4   308.214      CHF  Bills for Collection      00389604-0001
#
#                 APPLICANT_NAME  \
# 0  SUNSTEEL INDUSTRIES LIMITED
# 1              NESTLE NIG. PLC
# 2              NESTLE NIG. PLC
# ...

# %% [markdown]
# #### Export the Clean Data

# %%
# Export current clean dataframe
df.to_csv("Clean Nigerian Export df.csv" , index=False)

# %% [markdown]
# #### import the Clean Data

# %%
df = pd.read_csv("Clean Nigerian Export df.csv")

# %% [markdown]
# Tableau dashboard : https://public.tableau.com/app/profile/olawuwo.abideen/viz/NigerianExport/NigeriaExport?publish=yes
